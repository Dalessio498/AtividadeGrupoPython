# %%
import pandas as pd 
# Tabela 1: Clientes 
data_clientes = { 
 'ID_Cliente': [1, 2, 3, 4], 
 'Nome': ['Ana', 'Bruno', 'Carla', 'Daniel'] 
} 
df_clientes = pd.DataFrame(data_clientes) 
print("--- Clientes ---") 
print(df_clientes) 
print("\n")
# Out:
# --- Clientes ---
#    ID_Cliente    Nome
# 0           1     Ana
# 1           2   Bruno
# 2           3   Carla
# 3           4  Daniel

# %%
data_pedidos = { 
 'ID_Pedido': [101, 102, 103], 
 'ID_Cliente': [2, 3, 2], # Note: Ana(1) e Daniel(4) não têm pedidos 
 'Produto': ['Notebook', 'Mouse', 'Teclado'] 
} 
df_pedidos = pd.DataFrame(data_pedidos) 
print("--- Pedidos ---") 
print(df_pedidos) 
print("\n") 
# --- O MERGE --- 
# Vamos mesclar as duas tabelas usando a coluna 'ID_Cliente' 
# Por padrão, o 'merge' faz um 'inner join' (só inclui quem está nas duas tabelas) 
df_merged = pd.merge(df_clientes, df_pedidos, on='ID_Cliente') 
print("--- Resultado do Merge (Inner Join) ---") 
print(df_merged)
# Out:
# --- Pedidos ---
#    ID_Pedido  ID_Cliente   Produto
# 0        101           2  Notebook
# 1        102           3     Mouse
# 2        103           2   Teclado
#
#
# --- Resultado do Merge (Inner Join) ---
#    ID_Cliente   Nome  ID_Pedido   Produto
# 0           2  Bruno        101  Notebook
# 1           2  Bruno        103   Teclado
# 2           3  Carla        102     Mouse

# %%
import pandas as pd

# ------------------------------------------------------

# Tabela 1 - CLIENTES 
# ------------------------------------------------------ 
# Criamos um DataFrame contendo informações dos clientes: 
# ID_Cliente → identificador único 
# Nome → nome do cliente 
# Cidade → localidade do cliente 
clientes = pd.DataFrame({ 
 "ID_Cliente": [1, 2, 3, 4, 5], 
 "Nome": ["Ana", "Bruno", "Carlos", "Diana", "Eduardo"], 
 "Cidade": ["SP", "RJ", "SP", "BH", "Curitiba"] 
}) 
print("\n--- CLIENTES ---") 
print(clientes) # Exibe o DataFrame de clientes 
# ------------------------------------------------------ 
# Tabela 2 - PRODUTOS 
# ------------------------------------------------------ 
# Informações sobre os produtos 
# ID_Produto → identificador único 
# Produto → nome do produto 
# Categoria → tipo do produto 
# Preco → valor unitário 
produtos = pd.DataFrame({ 
 "ID_Produto": [101, 102, 103, 104], 
 "Produto": ["Notebook", "Mouse", "Teclado", "Monitor"], 
 "Categoria": ["Eletrônicos", "Eletrônicos", "Eletrônicos", "Eletrônicos"], 
 "Preco": [3500, 80, 120, 900] 
})
print("\n--- PRODUTOS ---") 
print(produtos) # Exibe o DataFrame de produtos 
# ------------------------------------------------------ 
# Tabela 3 - VENDAS 
# ------------------------------------------------------ 
# Informações das vendas 
# ID_Venda → identificador da venda 
# ID_Cliente → referência ao cliente comprador 
# ID_Produto → referência ao produto vendido 
# Quantidade → quantidade comprada 
vendas = pd.DataFrame({ 
 "ID_Venda": [1, 2, 3, 4, 5, 6], 
 "ID_Cliente": [1, 3, 2, 4, 5, 1], 
 "ID_Produto": [101, 102, 104, 103, 101, 102], 
 "Quantidade": [1, 2, 1, 3, 1, 2] 
}) 
print("\n--- VENDAS ---") 
print(vendas) # Exibe o DataFrame de vendas 

# Fazemos a junção (merge) das tabelas vendas + clientes 
# Usando como chave a coluna ID_Cliente 
df = vendas.merge(clientes, on="ID_Cliente").merge(produtos, on="ID_Produto") # Depois juntamos com produtos usando ID_Produto 
# Criamos uma nova coluna "Total" multiplicando quantidade * preço 
df["Total"] = df["Quantidade"] * df["Preco"] 
print("\n--- RELATÓRIO COMPLETO ---") 
print(df) # Exibe o DataFrame resultante com todas as informações unificadas 
# Agrupa por nome do cliente e soma o total gasto 
# groupby → organiza os dados por cliente 
# sum() → soma os valores de Total 
total_por_cliente = df.groupby("Nome")["Total"].sum() 
print("\n--- Total Vendido por Cliente ---") 
print(total_por_cliente) 
# Agrupa por nome do produto e soma o total vendido 
total_por_produto = df.groupby("Produto")["Total"].sum() 
print("\n--- Total Vendido por Produto ---") 
print(total_por_produto) 
# Agrupa pelos nomes das cidades e soma a quantidade vendida 
qtd_por_cidade = df.groupby("Cidade")["Quantidade"].sum() 
print("\n--- Quantidade Vendida por Cidade ---") 
print(qtd_por_cidade) 
# Agrupa por categoria e soma as quantidades vendidas 
qtd_por_categoria = df.groupby("Categoria")["Quantidade"].sum()
print("\n--- Quantidade Vendida por Categoria ---") 
print(qtd_por_categoria) 
# Filtra apenas as linhas em que o Nome é "Ana" 
filtro_ana = df[df["Nome"] == "Ana"]
print("\n--- Vendas de Ana ---") 
print(filtro_ana) 
# Salva o DataFrame completo em um arquivo Excel # index=False → evita que o índice seja salvo como coluna 
df.to_excel("vendas_completas.xlsx", index=False) 
print("Arquivo criado com sucesso")
# Out:
# --- CLIENTES ---
#    ID_Cliente     Nome    Cidade
# 0           1      Ana        SP
# 1           2    Bruno        RJ
# 2           3   Carlos        SP
# 3           4    Diana        BH
# 4           5  Eduardo  Curitiba
#
# --- PRODUTOS ---
#    ID_Produto   Produto    Categoria  Preco
# 0         101  Notebook  Eletrônicos   3500
# 1         102     Mouse  Eletrônicos     80
# 2         103   Teclado  Eletrônicos    120
# 3         104   Monitor  Eletrônicos    900
#
# --- VENDAS ---
#    ID_Venda  ID_Cliente  ID_Produto  Quantidade
# 0         1           1         101           1
# 1         2           3         102           2
# 2         3           2         104           1
# 3         4           4         103           3
# 4         5           5         101           1
# 5         6           1         102           2
#
# --- RELATÓRIO COMPLETO ---
#    ID_Venda  ID_Cliente  ID_Produto  Quantidade     Nome    Cidade   Produto  \
# 0         1           1         101           1      Ana        SP  Notebook
# 1         2           3         102           2   Carlos        SP     Mouse
# 2         3           2         104           1    Bruno        RJ   Monitor
# 3         4           4         103           3    Diana        BH   Teclado
# 4         5           5         101           1  Eduardo  Curitiba  Notebook
# 5         6           1         102           2      Ana        SP     Mouse
#
#      Categoria  Preco  Total
# 0  Eletrônicos   3500   3500
# 1  Eletrônicos     80    160
# 2  Eletrônicos    900    900
# 3  Eletrônicos    120    360
# 4  Eletrônicos   3500   3500
# 5  Eletrônicos     80    160
#
# --- Total Vendido por Cliente ---
# Nome
# Ana        3660
# Bruno       900
# Carlos      160
# Diana       360
# Eduardo    3500
# Name: Total, dtype: int64
#
# --- Total Vendido por Produto ---
# Produto
# Monitor      900
# Mouse        320
# Notebook    7000
# Teclado      360
# Name: Total, dtype: int64
#
# --- Quantidade Vendida por Cidade ---
# Cidade
# BH          3
# Curitiba    1
# RJ          1
# SP          5
# Name: Quantidade, dtype: int64
#
# --- Quantidade Vendida por Categoria ---
# Categoria
# Eletrônicos    10
# Name: Quantidade, dtype: int64
#
# --- Vendas de Ana ---
#    ID_Venda  ID_Cliente  ID_Produto  Quantidade Nome Cidade   Produto  \
# 0         1           1         101           1  Ana     SP  Notebook
# 5         6           1         102           2  Ana     SP     Mouse
#
#      Categoria  Preco  Total
# 0  Eletrônicos   3500   3500
# 5  Eletrônicos     80    160
# Arquivo criado com sucesso
